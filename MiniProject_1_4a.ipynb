# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import concurrent.futures

# %%
def OMP(A, y, s, noise, n_norm):
    N = A.shape[1]
    M = A.shape[0]
    k = []                           
    a = np.empty((M, 0))  
    r = y                            

    while max(np.abs(A.T @ r)) > 0.1:
        x_omp = np.zeros((N, 1))
        j = np.argmax(np.abs(A.T @ r))
        k.append(j)

        a = np.hstack([a, A[:, j].reshape(M, 1)])

        a_temp = np.linalg.inv(a.T @ a)
        alpha = a_temp @ a.T @ y
        b = a @ alpha
        r = y - b

        for i in range(len(k)):
            x_omp[k[i], 0] = alpha[i]
        error = np.linalg.norm(y - A @ x_omp)

        if noise:
            if error < n_norm or len(k) == s:
                break
        else:
            if error < 1e-3:
                break

    for i in range(len(k)):
        x_omp[k[i], 0] = alpha[i]

    return x_omp, len(k)

# %%
import numpy as np
import random
import concurrent.futures

def parallel_monte_carlo(N, s_max, A_normal_upper, sigma):
    def monte_carlo_simulation(M, s, N, A_normal_upper, sigma, mc_time=2000):
        success, success_large = 0, 0
        avg_error, avg_error_large = 0, 0
        for iter in range(mc_time):
            print(f"Processing m={M}, s={s}, iteration={iter+1}/{mc_time}")

            A = np.random.normal(0, A_normal_upper, (M, N))
            A = A / np.linalg.norm(A, axis=0)

            x = np.zeros((N, 1))

            j = random.sample(range(N), s)
            x[j] = random.randint(-10, 10)
            while sum(x[j] == 0):
                x[j] = random.randint(-10, 10)

            n = np.random.normal(0, sigma[0], (M, 1))
            n_large = np.random.normal(0, sigma[1], (M, 1))

            y = ((A @ x) + n)
            y_large = ((A @ x) + n_large)
            x_omp, s_cap = OMP(A, y, s, True, 0)
            x_omp_large, s_cap_large = OMP(A, y_large, s, True, 0)
            error = np.linalg.norm(x - x_omp) / np.linalg.norm(x)
            error_large = np.linalg.norm(x - x_omp_large) / np.linalg.norm(x)

            avg_error += error
            avg_error_large += error_large

            if error < 1e-3:
                success += 1
            if error_large < 1e-3:
                success_large += 1

        return success / mc_time, success_large / mc_time, avg_error / mc_time, avg_error_large / mc_time

    success_plot, success_plot_large, avg_error_plot, avg_error_plot_large = [], [], [], []
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = {}
        for M in range(1, N):
            for s in range(1, s_max):
                future = executor.submit(monte_carlo_simulation, M, s, N, A_normal_upper, sigma)
                futures[future] = (M, s)

        for future in concurrent.futures.as_completed(futures):
            M, s = futures[future]
            success, success_large, avg_error, avg_error_large = future.result()

            while len(success_plot) <= M:
                success_plot.append([])
                success_plot_large.append([])
                avg_error_plot.append([])
                avg_error_plot_large.append([])

            success_plot[M - 1].append(success)
            success_plot_large[M - 1].append(success_large)
            avg_error_plot[M - 1].append(avg_error)
            avg_error_plot_large[M - 1].append(avg_error_large)

    def pad_and_convert_to_array(list_of_lists):
        max_length = max(len(sublist) for sublist in list_of_lists)
        padded_list = [sublist + [0] * (max_length - len(sublist)) for sublist in list_of_lists]
        return np.array(padded_list, dtype=float)

    success_plot = pad_and_convert_to_array(success_plot)
    success_plot_large = pad_and_convert_to_array(success_plot_large)
    avg_error_plot = pad_and_convert_to_array(avg_error_plot)
    avg_error_plot_large = pad_and_convert_to_array(avg_error_plot_large)


    return success_plot, success_plot_large, avg_error_plot, avg_error_plot_large

# %%
N = 20
s_max = 20
# N = 50
# s_max = 20
# N = 100
# s_max = 20
A_normal_upper = 1
sigma = [0.1, 10]
success_plot, success_plot_large, avg_error_plot, avg_error_plot_large = parallel_monte_carlo(N, s_max, A_normal_upper, sigma)
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing m=19, s=15, iteration=1593/2000
# Processing m=19, s=19, iteration=526/2000
# Processing m=19, s=18, iteration=774/2000
# Processing m=19, s=19, iteration=527/2000
# Processing m=19, s=17, iteration=933/2000
# Processing m=19, s=16, iteration=1179/2000
# Processing m=19, s=17, iteration=934/2000Processing m=19, s=15, iteration=1594/2000Processing m=19, s=18, iteration=775/2000
# Processing m=19, s=19, iteration=528/2000
#
#
# Processing m=19, s=16, iteration=1180/2000
# Processing m=19, s=19, iteration=529/2000Processing m=19, s=18, iteration=776/2000Processing m=19, s=15, iteration=1595/2000Processing m=19, s=17, iteration=935/2000
#
#
#
# Processing m=19, s=19, iteration=530/2000Processing m=19, s=17, iteration=936/2000
#
# Processing m=19, s=16, iteration=1181/2000
# Processing m=19, s=18, iteration=777/2000Processing m=19, s=15, iteration=1596/2000
# Processing m=19, s=17, iteration=937/2000
# Processing m=19, s=16, iteration=1182/2000
# Processing m=19, s=19, iteration=531/2000
#
# Processing m=19, s=18, iteration=778/2000
# Processing m=19, s=15, iteration=1597/2000
# Processing m=19, s=19, iteration=532/2000
# Processing m=19, s=17, iteration=938/2000
# Processing m=19, s=16, iteration=1183/2000
# Processing m=19, s=15, iteration=1598/2000
# Processing m=19, s=17, iteration=939/2000Processing m=19, s=18, iteration=779/2000
#
# Processing m=19, s=16, iteration=1184/2000
# Processing m=19, s=15, iteration=1599/2000Processing m=19, s=19, iteration=533/2000
#
# Processing m=19, s=17, iteration=940/2000
# Processing m=19, s=16, iteration=1185/2000Processing m=19, s=18, iteration=780/2000
#
# Processing m=19, s=18, iteration=781/2000
# Processing m=19, s=17, iteration=941/2000
# Processing m=19, s=15, iteration=1600/2000Processing m=19, s=19, iteration=534/2000
#
# Processing m=19, s=16, iteration=1186/2000Processing m=19, s=18, iteration=782/2000
#
# Processing m=19, s=17, iteration=942/2000Processing m=19, s=19, iteration=535/2000Processing m=19, s=15, iteration=1601/2000
#
# Processing m=19, s=16, iteration=1187/2000Processing m=19, s=18, iteration=783/2000
#
# Processing m=19, s=15, iteration=1602/2000
#
# Processing m=19, s=16, iteration=1188/2000
# Processing m=19, s=17, iteration=943/2000
# Processing m=19, s=19, iteration=536/2000
# Processing m=19, s=18, iteration=784/2000
# Processing m=19, s=15, iteration=1603/2000
# Processing m=19, s=17, iteration=944/2000
# Processing m=19, s=16, iteration=1189/2000
# Processing m=19, s=18, iteration=785/2000
# Processing m=19, s=19, iteration=537/2000
# Processing m=19, s=16, iteration=1190/2000
# Processing m=19, s=15, iteration=1604/2000
# Processing m=19, s=17, iteration=945/2000
# Processing m=19, s=19, iteration=538/2000
# Processing m=19, s=18, iteration=786/2000
# Processing m=19, s=17, iteration=946/2000
# Processing m=19, s=16, iteration=1191/2000
# Processing m=19, s=15, iteration=1605/2000
# Processing m=19, s=19, iteration=539/2000
# Processing m=19, s=17, iteration=947/2000
# Processing m=19, s=18, iteration=787/2000
# Processing m=19, s=15, iteration=1606/2000
# Processing m=19, s=16, iteration=1192/2000
# Processing m=19, s=19, iteration=540/2000
# Processing m=19, s=17, iteration=948/2000
# Processing m=19, s=18, iteration=788/2000
# Processing m=19, s=15, iteration=1607/2000
# Processing m=19, s=19, iteration=541/2000
# Processing m=19, s=16, iteration=1193/2000
# Processing m=19, s=18, iteration=789/2000
# Processing m=19, s=19, iteration=542/2000
# Processing m=19, s=17, iteration=949/2000
# Processing m=19, s=15, iteration=1608/2000
# Processing m=19, s=16, iteration=1194/2000
# Processing m=19, s=15, iteration=1609/2000
# Processing m=19, s=18, iteration=790/2000
# Processing m=19, s=17, iteration=950/2000
# Processing m=19, s=19, iteration=543/2000
# Processing m=19, s=16, iteration=1195/2000
# Processing m=19, s=18, iteration=791/2000
# Processing m=19, s=17, iteration=951/2000
# Processing m=19, s=15, iteration=1610/2000
# Processing m=19, s=19, iteration=544/2000
# Processing m=19, s=16, iteration=1196/2000
# Processing m=19, s=18, iteration=792/2000
# Processing m=19, s=17, iteration=952/2000
# Processing m=19, s=15, iteration=1611/2000
# Processing m=19, s=16, iteration=1197/2000
# Processing m=19, s=19, iteration=545/2000
# Processing m=19, s=15, iteration=1612/2000
# Processing m=19, s=18, iteration=793/2000
# Processing m=19, s=17, iteration=953/2000
# Processing m=19, s=19, iteration=546/2000
# Processing m=19, s=16, iteration=1198/2000
# Processing m=19, s=18, iteration=794/2000
# Processing m=19, s=15, iteration=1613/2000
# Processing m=19, s=19, iteration=547/2000
# Processing m=19, s=17, iteration=954/2000
# Processing m=19, s=16, iteration=1199/2000
# Processing m=19, s=18, iteration=795/2000
# Processing m=19, s=16, iteration=1200/2000
# Processing m=19, s=19, iteration=548/2000
# Processing m=19, s=17, iteration=955/2000
# Processing m=19, s=15, iteration=1614/2000
# Processing m=19, s=18, iteration=796/2000
# Processing m=19, s=15, iteration=1615/2000
# Processing m=19, s=19, iteration=549/2000
# Processing m=19, s=16, iteration=1201/2000
# Processing m=19, s=17, iteration=956/2000
# Processing m=19, s=15, iteration=1616/2000
# Processing m=19, s=18, iteration=797/2000
# Processing m=19, s=19, iteration=550/2000
# Processing m=19, s=17, iteration=957/2000
# Processing m=19, s=16, iteration=1202/2000
# Processing m=19, s=15, iteration=1617/2000
# Processing m=19, s=19, iteration=551/2000
# Processing m=19, s=18, iteration=798/2000
# Processing m=19, s=16, iteration=1203/2000
# Processing m=19, s=17, iteration=958/2000
# Processing m=19, s=15, iteration=1618/2000
# Processing m=19, s=18, iteration=799/2000
# Processing m=19, s=19, iteration=552/2000
# Processing m=19, s=16, iteration=1204/2000
# Processing m=19, s=18, iteration=800/2000
# Processing m=19, s=17, iteration=959/2000
# Processing m=19, s=15, iteration=1619/2000
# Processing m=19, s=19, iteration=553/2000
# Processing m=19, s=17, iteration=960/2000
# Processing m=19, s=16, iteration=1205/2000Processing m=19, s=18, iteration=801/2000
# Processing m=19, s=15, iteration=1620/2000
#
# Processing m=19, s=19, iteration=554/2000
# Processing m=19, s=15, iteration=1621/2000
# Processing m=19, s=18, iteration=802/2000
# Processing m=19, s=16, iteration=1206/2000
# Processing m=19, s=17, iteration=961/2000
# Processing m=19, s=19, iteration=555/2000
# Processing m=19, s=15, iteration=1622/2000
# Processing m=19, s=18, iteration=803/2000
# Processing m=19, s=16, iteration=1207/2000
# Processing m=19, s=17, iteration=962/2000
# Processing m=19, s=19, iteration=556/2000
# Processing m=19, s=15, iteration=1623/2000
# Processing m=19, s=18, iteration=804/2000
# Processing m=19, s=16, iteration=1208/2000
# Processing m=19, s=17, iteration=963/2000
# Processing m=19, s=19, iteration=557/2000
# Processing m=19, s=15, iteration=1624/2000
# Processing m=19, s=16, iteration=1209/2000
# Processing m=19, s=18, iteration=805/2000
# Processing m=19, s=19, iteration=558/2000
# Processing m=19, s=15, iteration=1625/2000
# Processing m=19, s=17, iteration=964/2000
# Processing m=19, s=16, iteration=1210/2000
# Processing m=19, s=18, iteration=806/2000
# Processing m=19, s=19, iteration=559/2000
# Processing m=19, s=17, iteration=965/2000
# Processing m=19, s=15, iteration=1626/2000
# Processing m=19, s=18, iteration=807/2000
# Processing m=19, s=17, iteration=966/2000Processing m=19, s=15, iteration=1627/2000
#
# Processing m=19, s=18, iteration=808/2000
# Processing m=19, s=16, iteration=1211/2000
# Processing m=19, s=17, iteration=967/2000Processing m=19, s=15, iteration=1628/2000
#
# Processing m=19, s=19, iteration=560/2000
# Processing m=19, s=18, iteration=809/2000
# Processing m=19, s=19, iteration=561/2000Processing m=19, s=16, iteration=1212/2000Processing m=19, s=17, iteration=968/2000
# Processing m=19, s=15, iteration=1629/2000
#
#
# Processing m=19, s=18, iteration=810/2000
# Processing m=19, s=16, iteration=1213/2000Processing m=19, s=19, iteration=562/2000Processing m=19, s=17, iteration=969/2000Processing m=19, s=15, iteration=1630/2000
#
#
#
# Processing m=19, s=18, iteration=811/2000
# Processing m=19, s=16, iteration=1214/2000
# Processing m=19, s=15, iteration=1631/2000
# Processing m=19, s=17, iteration=970/2000
# Processing m=19, s=18, iteration=812/2000
# Processing m=19, s=19, iteration=563/2000
# Processing m=19, s=17, iteration=971/2000Processing m=19, s=19, iteration=564/2000
# Processing m=19, s=16, iteration=1215/2000Processing m=19, s=15, iteration=1632/2000
#
#
# Processing m=19, s=18, iteration=813/2000
# Processing m=19, s=17, iteration=972/2000Processing m=19, s=16, iteration=1216/2000Processing m=19, s=15, iteration=1633/2000
#
# Processing m=19, s=19, iteration=565/2000
#
# Processing m=19, s=19, iteration=566/2000
# Processing m=19, s=18, iteration=814/2000
# Processing m=19, s=17, iteration=973/2000
# Processing m=19, s=16, iteration=1217/2000
# Processing m=19, s=15, iteration=1634/2000
# Processing m=19, s=18, iteration=815/2000
# Processing m=19, s=19, iteration=567/2000
# Processing m=19, s=16, iteration=1218/2000
# Processing m=19, s=17, iteration=974/2000
# Processing m=19, s=15, iteration=1635/2000
# Processing m=19, s=18, iteration=816/2000
# Processing m=19, s=17, iteration=975/2000
# Processing m=19, s=19, iteration=568/2000
# Processing m=19, s=16, iteration=1219/2000
# Processing m=19, s=17, iteration=976/2000
# Processing m=19, s=18, iteration=817/2000
# Processing m=19, s=19, iteration=569/2000
# Processing m=19, s=15, iteration=1636/2000
# Processing m=19, s=16, iteration=1220/2000
# Processing m=19, s=18, iteration=818/2000Processing m=19, s=19, iteration=570/2000Processing m=19, s=15, iteration=1637/2000Processing m=19, s=17, iteration=977/2000
#
#
#
# Processing m=19, s=16, iteration=1221/2000
# Processing m=19, s=17, iteration=978/2000
# Processing m=19, s=15, iteration=1638/2000
# Processing m=19, s=16, iteration=1222/2000
# Processing m=19, s=18, iteration=819/2000
# Processing m=19, s=15, iteration=1639/2000
# Processing m=19, s=18, iteration=820/2000
# Processing m=19, s=19, iteration=571/2000
# Processing m=19, s=17, iteration=979/2000
# Processing m=19, s=16, iteration=1223/2000
# Processing m=19, s=15, iteration=1640/2000
# Processing m=19, s=17, iteration=980/2000
# Processing m=19, s=18, iteration=821/2000
# Processing m=19, s=19, iteration=572/2000
# Processing m=19, s=15, iteration=1641/2000Processing m=19, s=16, iteration=1224/2000
#
# Processing m=19, s=17, iteration=981/2000Processing m=19, s=18, iteration=822/2000Processing m=19, s=19, iteration=573/2000
#
#
# Processing m=19, s=16, iteration=1225/2000Processing m=19, s=15, iteration=1642/2000
#
# Processing m=19, s=19, iteration=574/2000Processing m=19, s=17, iteration=982/2000Processing m=19, s=18, iteration=823/2000
#
# Processing m=19, s=15, iteration=1643/2000
#
# Processing m=19, s=16, iteration=1226/2000Processing m=19, s=18, iteration=824/2000Processing m=19, s=17, iteration=983/2000
#
#
# Processing m=19, s=15, iteration=1644/2000
# Processing m=19, s=17, iteration=984/2000Processing m=19, s=18, iteration=825/2000Processing m=19, s=19, iteration=575/2000Processing m=19, s=16, iteration=1227/2000
#
# Processing m=19, s=15, iteration=1645/2000
#
#
# Processing m=19, s=19, iteration=576/2000
# Processing m=19, s=18, iteration=826/2000
# Processing m=19, s=17, iteration=985/2000
# Processing m=19, s=15, iteration=1646/2000
# Processing m=19, s=16, iteration=1228/2000
# Processing m=19, s=18, iteration=827/2000
# Processing m=19, s=17, iteration=986/2000
# Processing m=19, s=15, iteration=1647/2000Processing m=19, s=16, iteration=1229/2000
# Processing m=19, s=19, iteration=577/2000
# Processing m=19, s=18, iteration=828/2000Processing m=19, s=17, iteration=987/2000
#
#
# Processing m=19, s=15, iteration=1648/2000
# Processing m=19, s=17, iteration=988/2000Processing m=19, s=16, iteration=1230/2000
# Processing m=19, s=19, iteration=578/2000Processing m=19, s=18, iteration=829/2000
#
#
# Processing m=19, s=16, iteration=1231/2000Processing m=19, s=15, iteration=1649/2000Processing m=19, s=17, iteration=989/2000
#
#
# Processing m=19, s=19, iteration=579/2000
# Processing m=19, s=18, iteration=830/2000
# Processing m=19, s=15, iteration=1650/2000
# Processing m=19, s=16, iteration=1232/2000
# Processing m=19, s=19, iteration=580/2000Processing m=19, s=18, iteration=831/2000Processing m=19, s=17, iteration=990/2000
#
#
# Processing m=19, s=15, iteration=1651/2000Processing m=19, s=19, iteration=581/2000
# Processing m=19, s=16, iteration=1233/2000
# Processing m=19, s=18, iteration=832/2000
#
# Processing m=19, s=17, iteration=991/2000
# Processing m=19, s=19, iteration=582/2000
# Processing m=19, s=15, iteration=1652/2000
# Processing m=19, s=17, iteration=992/2000
# Processing m=19, s=15, iteration=1653/2000Processing m=19, s=16, iteration=1234/2000Processing m=19, s=19, iteration=583/2000
#
# Processing m=19, s=17, iteration=993/2000
# Processing m=19, s=18, iteration=833/2000
#
# Processing m=19, s=16, iteration=1235/2000
# Processing m=19, s=18, iteration=834/2000
# Processing m=19, s=17, iteration=994/2000
# Processing m=19, s=15, iteration=1654/2000
# Processing m=19, s=19, iteration=584/2000
# Processing m=19, s=19, iteration=585/2000Processing m=19, s=16, iteration=1236/2000Processing m=19, s=15, iteration=1655/2000
# Processing m=19, s=18, iteration=835/2000
# Processing m=19, s=17, iteration=995/2000
#
#
# Processing m=19, s=19, iteration=586/2000
# Processing m=19, s=15, iteration=1656/2000
# Processing m=19, s=16, iteration=1237/2000
# Processing m=19, s=18, iteration=836/2000
# Processing m=19, s=17, iteration=996/2000
# Processing m=19, s=15, iteration=1657/2000
# Processing m=19, s=16, iteration=1238/2000
# Processing m=19, s=19, iteration=587/2000Processing m=19, s=17, iteration=997/2000
# Processing m=19, s=18, iteration=837/2000
#
# Processing m=19, s=16, iteration=1239/2000
# Processing m=19, s=19, iteration=588/2000
# Processing m=19, s=18, iteration=838/2000Processing m=19, s=15, iteration=1658/2000
# Processing m=19, s=17, iteration=998/2000
#
# Processing m=19, s=16, iteration=1240/2000
# Processing m=19, s=19, iteration=589/2000
# Processing m=19, s=17, iteration=999/2000
# Processing m=19, s=15, iteration=1659/2000
# Processing m=19, s=18, iteration=839/2000
# Processing m=19, s=16, iteration=1241/2000
# Processing m=19, s=18, iteration=840/2000Processing m=19, s=15, iteration=1660/2000
#
# Processing m=19, s=19, iteration=590/2000
# Processing m=19, s=17, iteration=1000/2000
# Processing m=19, s=16, iteration=1242/2000
# Processing m=19, s=15, iteration=1661/2000Processing m=19, s=18, iteration=841/2000Processing m=19, s=19, iteration=591/2000
#
# Processing m=19, s=16, iteration=1243/2000
# Processing m=19, s=17, iteration=1001/2000
#
# Processing m=19, s=15, iteration=1662/2000
# Processing m=19, s=18, iteration=842/2000
# Processing m=19, s=19, iteration=592/2000
# Processing m=19, s=19, iteration=593/2000
# Processing m=19, s=18, iteration=843/2000
# Processing m=19, s=16, iteration=1244/2000
# Processing m=19, s=15, iteration=1663/2000
# Processing m=19, s=17, iteration=1002/2000
# Processing m=19, s=16, iteration=1245/2000
# Processing m=19, s=19, iteration=594/2000
# Processing m=19, s=18, iteration=844/2000
# Processing m=19, s=15, iteration=1664/2000
# Processing m=19, s=17, iteration=1003/2000
# Processing m=19, s=19, iteration=595/2000
# Processing m=19, s=18, iteration=845/2000
# Processing m=19, s=15, iteration=1665/2000
# Processing m=19, s=16, iteration=1246/2000
# Processing m=19, s=17, iteration=1004/2000Processing m=19, s=19, iteration=596/2000
# Processing m=19, s=16, iteration=1247/2000Processing m=19, s=15, iteration=1666/2000Processing m=19, s=18, iteration=846/2000
#
#
#
# Processing m=19, s=17, iteration=1005/2000
# Processing m=19, s=16, iteration=1248/2000
# Processing m=19, s=18, iteration=847/2000
# Processing m=19, s=15, iteration=1667/2000
# Processing m=19, s=19, iteration=597/2000
# Processing m=19, s=17, iteration=1006/2000
# Processing m=19, s=18, iteration=848/2000
# Processing m=19, s=15, iteration=1668/2000
# Processing m=19, s=16, iteration=1249/2000
# Processing m=19, s=19, iteration=598/2000
# Processing m=19, s=17, iteration=1007/2000
# Processing m=19, s=15, iteration=1669/2000
# Processing m=19, s=19, iteration=599/2000
# Processing m=19, s=18, iteration=849/2000
# Processing m=19, s=17, iteration=1008/2000
# Processing m=19, s=16, iteration=1250/2000
# Processing m=19, s=19, iteration=600/2000
# Processing m=19, s=18, iteration=850/2000
# Processing m=19, s=15, iteration=1670/2000
# Processing m=19, s=16, iteration=1251/2000
# Processing m=19, s=17, iteration=1009/2000
# Processing m=19, s=19, iteration=601/2000
# Processing m=19, s=18, iteration=851/2000
# Processing m=19, s=15, iteration=1671/2000
# Processing m=19, s=16, iteration=1252/2000
# Processing m=19, s=17, iteration=1010/2000
# Processing m=19, s=18, iteration=852/2000
# Processing m=19, s=19, iteration=602/2000
# Processing m=19, s=16, iteration=1253/2000
# Processing m=19, s=19, iteration=603/2000
# Processing m=19, s=18, iteration=853/2000
# Processing m=19, s=15, iteration=1672/2000
# Processing m=19, s=17, iteration=1011/2000
# Processing m=19, s=16, iteration=1254/2000
# Processing m=19, s=19, iteration=604/2000
# Processing m=19, s=18, iteration=854/2000
# Processing m=19, s=15, iteration=1673/2000
# Processing m=19, s=15, iteration=1674/2000
# Processing m=19, s=17, iteration=1012/2000
# Processing m=19, s=16, iteration=1255/2000
# Processing m=19, s=19, iteration=605/2000
# Processing m=19, s=17, iteration=1013/2000
# Processing m=19, s=15, iteration=1675/2000
# Processing m=19, s=19, iteration=606/2000
# Processing m=19, s=15, iteration=1676/2000
# Processing m=19, s=18, iteration=855/2000
# Processing m=19, s=17, iteration=1014/2000
# Processing m=19, s=15, iteration=1677/2000Processing m=19, s=16, iteration=1256/2000Processing m=19, s=19, iteration=607/2000
#
#
# Processing m=19, s=17, iteration=1015/2000
# Processing m=19, s=18, iteration=856/2000
# Processing m=19, s=16, iteration=1257/2000
# Processing m=19, s=19, iteration=608/2000
# Processing m=19, s=17, iteration=1016/2000Processing m=19, s=15, iteration=1678/2000
#
# Processing m=19, s=18, iteration=857/2000
# Processing m=19, s=17, iteration=1017/2000
# Processing m=19, s=16, iteration=1258/2000
# Processing m=19, s=18, iteration=858/2000
# Processing m=19, s=15, iteration=1679/2000
# Processing m=19, s=19, iteration=609/2000
# Processing m=19, s=17, iteration=1018/2000
# Processing m=19, s=15, iteration=1680/2000
# Processing m=19, s=18, iteration=859/2000Processing m=19, s=16, iteration=1259/2000Processing m=19, s=19, iteration=610/2000
#
#
# Processing m=19, s=15, iteration=1681/2000Processing m=19, s=17, iteration=1019/2000
#
# Processing m=19, s=16, iteration=1260/2000Processing m=19, s=17, iteration=1020/2000Processing m=19, s=19, iteration=611/2000Processing m=19, s=18, iteration=860/2000
#
#
#
# Processing m=19, s=15, iteration=1682/2000
# Processing m=19, s=19, iteration=612/2000
# Processing m=19, s=17, iteration=1021/2000Processing m=19, s=15, iteration=1683/2000
# Processing m=19, s=16, iteration=1261/2000Processing m=19, s=18, iteration=861/2000
#
#
# Processing m=19, s=17, iteration=1022/2000Processing m=19, s=19, iteration=613/2000
# Processing m=19, s=15, iteration=1684/2000
# Processing m=19, s=18, iteration=862/2000Processing m=19, s=16, iteration=1262/2000
#
#
# Processing m=19, s=19, iteration=614/2000Processing m=19, s=17, iteration=1023/2000
#
# Processing m=19, s=18, iteration=863/2000Processing m=19, s=15, iteration=1685/2000Processing m=19, s=16, iteration=1263/2000
#
#
# Processing m=19, s=19, iteration=615/2000Processing m=19, s=17, iteration=1024/2000
#
# Processing m=19, s=18, iteration=864/2000Processing m=19, s=16, iteration=1264/2000
# Processing m=19, s=15, iteration=1686/2000Processing m=19, s=17, iteration=1025/2000
#
# Processing m=19, s=19, iteration=616/2000
#
# Processing m=19, s=16, iteration=1265/2000
# Processing m=19, s=18, iteration=865/2000
# Processing m=19, s=16, iteration=1266/2000Processing m=19, s=15, iteration=1687/2000
#
# Processing m=19, s=17, iteration=1026/2000
# Processing m=19, s=18, iteration=866/2000
# Processing m=19, s=16, iteration=1267/2000
# Processing m=19, s=19, iteration=617/2000
# Processing m=19, s=17, iteration=1027/2000Processing m=19, s=15, iteration=1688/2000
#
# Processing m=19, s=16, iteration=1268/2000Processing m=19, s=18, iteration=867/2000
#
# Processing m=19, s=19, iteration=618/2000
# Processing m=19, s=17, iteration=1028/2000
# Processing m=19, s=16, iteration=1269/2000Processing m=19, s=15, iteration=1689/2000
# Processing m=19, s=18, iteration=868/2000
#
# Processing m=19, s=19, iteration=619/2000Processing m=19, s=17, iteration=1029/2000
#
# Processing m=19, s=16, iteration=1270/2000Processing m=19, s=19, iteration=620/2000Processing m=19, s=15, iteration=1690/2000
# Processing m=19, s=17, iteration=1030/2000Processing m=19, s=18, iteration=869/2000
#
#
#
# Processing m=19, s=17, iteration=1031/2000Processing m=19, s=18, iteration=870/2000Processing m=19, s=15, iteration=1691/2000Processing m=19, s=16, iteration=1271/2000
#
#
# Processing m=19, s=19, iteration=621/2000
#
# Processing m=19, s=15, iteration=1692/2000Processing m=19, s=17, iteration=1032/2000
# Processing m=19, s=16, iteration=1272/2000
# Processing m=19, s=18, iteration=871/2000
#
# Processing m=19, s=19, iteration=622/2000
# Processing m=19, s=15, iteration=1693/2000
# Processing m=19, s=18, iteration=872/2000Processing m=19, s=16, iteration=1273/2000
# Processing m=19, s=17, iteration=1033/2000
#
# Processing m=19, s=19, iteration=623/2000
# Processing m=19, s=18, iteration=873/2000Processing m=19, s=16, iteration=1274/2000Processing m=19, s=17, iteration=1034/2000
#
#
# Processing m=19, s=15, iteration=1694/2000Processing m=19, s=19, iteration=624/2000
#
# Processing m=19, s=17, iteration=1035/2000Processing m=19, s=18, iteration=874/2000Processing m=19, s=16, iteration=1275/2000
#
# Processing m=19, s=15, iteration=1695/2000
#
# Processing m=19, s=19, iteration=625/2000
# Processing m=19, s=16, iteration=1276/2000Processing m=19, s=15, iteration=1696/2000Processing m=19, s=18, iteration=875/2000
#
#
# Processing m=19, s=17, iteration=1036/2000Processing m=19, s=19, iteration=626/2000
#
# Processing m=19, s=18, iteration=876/2000Processing m=19, s=16, iteration=1277/2000Processing m=19, s=15, iteration=1697/2000
#
# Processing m=19, s=17, iteration=1037/2000Processing m=19, s=19, iteration=627/2000
#
#
# Processing m=19, s=16, iteration=1278/2000Processing m=19, s=18, iteration=877/2000
#
# Processing m=19, s=15, iteration=1698/2000Processing m=19, s=19, iteration=628/2000Processing m=19, s=17, iteration=1038/2000
#
#
# Processing m=19, s=18, iteration=878/2000Processing m=19, s=17, iteration=1039/2000Processing m=19, s=16, iteration=1279/2000
#
# Processing m=19, s=15, iteration=1699/2000
#
# Processing m=19, s=19, iteration=629/2000Processing m=19, s=16, iteration=1280/2000
# Processing m=19, s=18, iteration=879/2000Processing m=19, s=15, iteration=1700/2000
#
# Processing m=19, s=17, iteration=1040/2000
#
# Processing m=19, s=19, iteration=630/2000Processing m=19, s=16, iteration=1281/2000
# Processing m=19, s=18, iteration=880/2000
#
# Processing m=19, s=17, iteration=1041/2000
# Processing m=19, s=15, iteration=1701/2000
# Processing m=19, s=19, iteration=631/2000Processing m=19, s=16, iteration=1282/2000
#
# Processing m=19, s=18, iteration=881/2000Processing m=19, s=17, iteration=1042/2000
#
# Processing m=19, s=15, iteration=1702/2000
# Processing m=19, s=16, iteration=1283/2000
# Processing m=19, s=18, iteration=882/2000Processing m=19, s=19, iteration=632/2000
#
# Processing m=19, s=17, iteration=1043/2000Processing m=19, s=15, iteration=1703/2000
#
# Processing m=19, s=16, iteration=1284/2000
# Processing m=19, s=18, iteration=883/2000Processing m=19, s=19, iteration=633/2000Processing m=19, s=17, iteration=1044/2000
# Processing m=19, s=15, iteration=1704/2000
#
#
# Processing m=19, s=16, iteration=1285/2000Processing m=19, s=18, iteration=884/2000
#
# Processing m=19, s=19, iteration=634/2000Processing m=19, s=15, iteration=1705/2000Processing m=19, s=17, iteration=1045/2000
#
#
# Processing m=19, s=19, iteration=635/2000Processing m=19, s=16, iteration=1286/2000Processing m=19, s=18, iteration=885/2000
# Processing m=19, s=15, iteration=1706/2000
#
# Processing m=19, s=17, iteration=1046/2000
#
# Processing m=19, s=19, iteration=636/2000Processing m=19, s=15, iteration=1707/2000Processing m=19, s=18, iteration=886/2000
#
#
# Processing m=19, s=16, iteration=1287/2000Processing m=19, s=17, iteration=1047/2000
#
# Processing m=19, s=15, iteration=1708/2000Processing m=19, s=18, iteration=887/2000
# Processing m=19, s=19, iteration=637/2000
#
# Processing m=19, s=16, iteration=1288/2000
# Processing m=19, s=17, iteration=1048/2000
# Processing m=19, s=19, iteration=638/2000
# Processing m=19, s=17, iteration=1049/2000Processing m=19, s=18, iteration=888/2000
#
# Processing m=19, s=16, iteration=1289/2000Processing m=19, s=15, iteration=1709/2000
# Processing m=19, s=19, iteration=639/2000
#
# Processing m=19, s=17, iteration=1050/2000
# Processing m=19, s=15, iteration=1710/2000
# Processing m=19, s=18, iteration=889/2000
# Processing m=19, s=16, iteration=1290/2000
# Processing m=19, s=19, iteration=640/2000
# Processing m=19, s=15, iteration=1711/2000
# Processing m=19, s=18, iteration=890/2000
# Processing m=19, s=19, iteration=641/2000
# Processing m=19, s=17, iteration=1051/2000
# Processing m=19, s=18, iteration=891/2000
# Processing m=19, s=16, iteration=1291/2000
# Processing m=19, s=15, iteration=1712/2000
# Processing m=19, s=16, iteration=1292/2000Processing m=19, s=19, iteration=642/2000
#
# Processing m=19, s=17, iteration=1052/2000
# Processing m=19, s=18, iteration=892/2000
# Processing m=19, s=15, iteration=1713/2000
# Processing m=19, s=17, iteration=1053/2000
# Processing m=19, s=19, iteration=643/2000
# Processing m=19, s=16, iteration=1293/2000
# Processing m=19, s=17, iteration=1054/2000
# Processing m=19, s=16, iteration=1294/2000
# Processing m=19, s=15, iteration=1714/2000
# Processing m=19, s=18, iteration=893/2000
# Processing m=19, s=17, iteration=1055/2000
# Processing m=19, s=19, iteration=644/2000
# Processing m=19, s=15, iteration=1715/2000
# Processing m=19, s=16, iteration=1295/2000
# Processing m=19, s=19, iteration=645/2000
# Processing m=19, s=18, iteration=894/2000
# Processing m=19, s=17, iteration=1056/2000
# Processing m=19, s=15, iteration=1716/2000
# Processing m=19, s=16, iteration=1296/2000
# Processing m=19, s=18, iteration=895/2000
# Processing m=19, s=19, iteration=646/2000
# Processing m=19, s=15, iteration=1717/2000
# Processing m=19, s=17, iteration=1057/2000
# Processing m=19, s=18, iteration=896/2000
# Processing m=19, s=16, iteration=1297/2000
# Processing m=19, s=17, iteration=1058/2000
# Processing m=19, s=15, iteration=1718/2000
# Processing m=19, s=19, iteration=647/2000
# Processing m=19, s=16, iteration=1298/2000
# Processing m=19, s=18, iteration=897/2000
# Processing m=19, s=15, iteration=1719/2000
# Processing m=19, s=19, iteration=648/2000
# Processing m=19, s=17, iteration=1059/2000
# Processing m=19, s=19, iteration=649/2000
# Processing m=19, s=15, iteration=1720/2000
# Processing m=19, s=18, iteration=898/2000
# Processing m=19, s=16, iteration=1299/2000
# Processing m=19, s=17, iteration=1060/2000
# Processing m=19, s=16, iteration=1300/2000
# Processing m=19, s=19, iteration=650/2000
# Processing m=19, s=15, iteration=1721/2000
# Processing m=19, s=18, iteration=899/2000Processing m=19, s=17, iteration=1061/2000
#
# Processing m=19, s=19, iteration=651/2000Processing m=19, s=15, iteration=1722/2000Processing m=19, s=16, iteration=1301/2000
#
#
# Processing m=19, s=18, iteration=900/2000
# Processing m=19, s=17, iteration=1062/2000
# Processing m=19, s=19, iteration=652/2000
# Processing m=19, s=15, iteration=1723/2000
# Processing m=19, s=16, iteration=1302/2000
# Processing m=19, s=15, iteration=1724/2000
# Processing m=19, s=19, iteration=653/2000
# Processing m=19, s=17, iteration=1063/2000
# Processing m=19, s=18, iteration=901/2000
# Processing m=19, s=16, iteration=1303/2000
# Processing m=19, s=19, iteration=654/2000
# Processing m=19, s=15, iteration=1725/2000
# Processing m=19, s=16, iteration=1304/2000
# Processing m=19, s=17, iteration=1064/2000
# Processing m=19, s=15, iteration=1726/2000
# Processing m=19, s=19, iteration=655/2000
# Processing m=19, s=18, iteration=902/2000
# Processing m=19, s=16, iteration=1305/2000
# Processing m=19, s=17, iteration=1065/2000
# Processing m=19, s=19, iteration=656/2000Processing m=19, s=18, iteration=903/2000
# Processing m=19, s=16, iteration=1306/2000Processing m=19, s=15, iteration=1727/2000
#
#
# Processing m=19, s=17, iteration=1066/2000
# Processing m=19, s=18, iteration=904/2000
# Processing m=19, s=16, iteration=1307/2000Processing m=19, s=15, iteration=1728/2000Processing m=19, s=19, iteration=657/2000
#
#
# Processing m=19, s=15, iteration=1729/2000Processing m=19, s=17, iteration=1067/2000Processing m=19, s=18, iteration=905/2000
#
# Processing m=19, s=19, iteration=658/2000
# Processing m=19, s=16, iteration=1308/2000
#
# Processing m=19, s=17, iteration=1068/2000Processing m=19, s=18, iteration=906/2000
#
# Processing m=19, s=15, iteration=1730/2000Processing m=19, s=19, iteration=659/2000Processing m=19, s=16, iteration=1309/2000
#
# Processing m=19, s=17, iteration=1069/2000
# Processing m=19, s=18, iteration=907/2000
#
# Processing m=19, s=15, iteration=1731/2000Processing m=19, s=19, iteration=660/2000
# Processing m=19, s=16, iteration=1310/2000
#
# Processing m=19, s=18, iteration=908/2000
# Processing m=19, s=17, iteration=1070/2000
# Processing m=19, s=15, iteration=1732/2000
# Processing m=19, s=16, iteration=1311/2000
# Processing m=19, s=18, iteration=909/2000
# Processing m=19, s=19, iteration=661/2000
# Processing m=19, s=17, iteration=1071/2000
# Processing m=19, s=16, iteration=1312/2000
# Processing m=19, s=19, iteration=662/2000
# Processing m=19, s=18, iteration=910/2000
# Processing m=19, s=15, iteration=1733/2000
# Processing m=19, s=17, iteration=1072/2000
# Processing m=19, s=18, iteration=911/2000
# Processing m=19, s=19, iteration=663/2000
# Processing m=19, s=15, iteration=1734/2000
# Processing m=19, s=16, iteration=1313/2000
# Processing m=19, s=17, iteration=1073/2000
# Processing m=19, s=16, iteration=1314/2000
# Processing m=19, s=15, iteration=1735/2000
# Processing m=19, s=18, iteration=912/2000
# Processing m=19, s=17, iteration=1074/2000
# Processing m=19, s=19, iteration=664/2000
# Processing m=19, s=16, iteration=1315/2000
# Processing m=19, s=15, iteration=1736/2000
# Processing m=19, s=18, iteration=913/2000
# Processing m=19, s=18, iteration=914/2000Processing m=19, s=16, iteration=1316/2000Processing m=19, s=17, iteration=1075/2000
#
#
# Processing m=19, s=19, iteration=665/2000Processing m=19, s=15, iteration=1737/2000
# Processing m=19, s=17, iteration=1076/2000
#
# Processing m=19, s=18, iteration=915/2000Processing m=19, s=16, iteration=1317/2000
#
# Processing m=19, s=19, iteration=666/2000
# Processing m=19, s=17, iteration=1077/2000
# Processing m=19, s=15, iteration=1738/2000
# Processing m=19, s=18, iteration=916/2000
# Processing m=19, s=15, iteration=1739/2000
# Processing m=19, s=17, iteration=1078/2000
# Processing m=19, s=16, iteration=1318/2000
# Processing m=19, s=19, iteration=667/2000Processing m=19, s=18, iteration=917/2000
# Processing m=19, s=17, iteration=1079/2000
#
# Processing m=19, s=15, iteration=1740/2000Processing m=19, s=19, iteration=668/2000
# Processing m=19, s=16, iteration=1319/2000
#
# Processing m=19, s=18, iteration=918/2000
# Processing m=19, s=15, iteration=1741/2000
# Processing m=19, s=17, iteration=1080/2000
# Processing m=19, s=19, iteration=669/2000
# Processing m=19, s=16, iteration=1320/2000
# Processing m=19, s=17, iteration=1081/2000
# Processing m=19, s=18, iteration=919/2000
# Processing m=19, s=16, iteration=1321/2000
# Processing m=19, s=15, iteration=1742/2000
# Processing m=19, s=19, iteration=670/2000
# Processing m=19, s=18, iteration=920/2000
# Processing m=19, s=15, iteration=1743/2000
# Processing m=19, s=19, iteration=671/2000
# Processing m=19, s=17, iteration=1082/2000
# Processing m=19, s=18, iteration=921/2000
# Processing m=19, s=16, iteration=1322/2000
# Processing m=19, s=19, iteration=672/2000
# Processing m=19, s=15, iteration=1744/2000
# Processing m=19, s=17, iteration=1083/2000
# Processing m=19, s=16, iteration=1323/2000
# Processing m=19, s=16, iteration=1324/2000
# Processing m=19, s=19, iteration=673/2000
# Processing m=19, s=18, iteration=922/2000
# Processing m=19, s=15, iteration=1745/2000
# Processing m=19, s=17, iteration=1084/2000
# Processing m=19, s=18, iteration=923/2000
# Processing m=19, s=16, iteration=1325/2000
# Processing m=19, s=19, iteration=674/2000
# Processing m=19, s=15, iteration=1746/2000Processing m=19, s=18, iteration=924/2000Processing m=19, s=16, iteration=1326/2000
# Processing m=19, s=17, iteration=1085/2000
#
#
# Processing m=19, s=19, iteration=675/2000
# Processing m=19, s=15, iteration=1747/2000
# Processing m=19, s=17, iteration=1086/2000
# Processing m=19, s=18, iteration=925/2000
# Processing m=19, s=16, iteration=1327/2000
# Processing m=19, s=19, iteration=676/2000
# Processing m=19, s=15, iteration=1748/2000Processing m=19, s=17, iteration=1087/2000
# Processing m=19, s=16, iteration=1328/2000Processing m=19, s=18, iteration=926/2000
#
#
# Processing m=19, s=19, iteration=677/2000
# Processing m=19, s=18, iteration=927/2000
# Processing m=19, s=15, iteration=1749/2000
# Processing m=19, s=17, iteration=1088/2000
# Processing m=19, s=16, iteration=1329/2000
# Processing m=19, s=15, iteration=1750/2000Processing m=19, s=19, iteration=678/2000Processing m=19, s=17, iteration=1089/2000
#
# Processing m=19, s=18, iteration=928/2000
#
# Processing m=19, s=16, iteration=1330/2000
# Processing m=19, s=19, iteration=679/2000Processing m=19, s=18, iteration=929/2000
# Processing m=19, s=15, iteration=1751/2000Processing m=19, s=17, iteration=1090/2000Processing m=19, s=16, iteration=1331/2000
#
#
#
# Processing m=19, s=18, iteration=930/2000
# Processing m=19, s=15, iteration=1752/2000Processing m=19, s=19, iteration=680/2000Processing m=19, s=16, iteration=1332/2000
# Processing m=19, s=17, iteration=1091/2000
#
#
# Processing m=19, s=18, iteration=931/2000
# Processing m=19, s=16, iteration=1333/2000Processing m=19, s=17, iteration=1092/2000
# Processing m=19, s=19, iteration=681/2000
# Processing m=19, s=18, iteration=932/2000Processing m=19, s=15, iteration=1753/2000
#
# Processing m=19, s=16, iteration=1334/2000
# Processing m=19, s=15, iteration=1754/2000
# Processing m=19, s=17, iteration=1093/2000
#
# Processing m=19, s=19, iteration=682/2000
# Processing m=19, s=17, iteration=1094/2000Processing m=19, s=18, iteration=933/2000
#
# Processing m=19, s=16, iteration=1335/2000
# Processing m=19, s=15, iteration=1755/2000
# Processing m=19, s=19, iteration=683/2000
# Processing m=19, s=18, iteration=934/2000
# Processing m=19, s=19, iteration=684/2000Processing m=19, s=15, iteration=1756/2000
#
# Processing m=19, s=17, iteration=1095/2000
# Processing m=19, s=18, iteration=935/2000Processing m=19, s=16, iteration=1336/2000
#
# Processing m=19, s=15, iteration=1757/2000
# Processing m=19, s=18, iteration=936/2000Processing m=19, s=16, iteration=1337/2000Processing m=19, s=19, iteration=685/2000
#
# Processing m=19, s=17, iteration=1096/2000
# Processing m=19, s=15, iteration=1758/2000
#
# Processing m=19, s=18, iteration=937/2000Processing m=19, s=16, iteration=1338/2000
#
# Processing m=19, s=19, iteration=686/2000
# Processing m=19, s=15, iteration=1759/2000
# Processing m=19, s=17, iteration=1097/2000
# Processing m=19, s=16, iteration=1339/2000
# Processing m=19, s=19, iteration=687/2000
# Processing m=19, s=18, iteration=938/2000
# Processing m=19, s=17, iteration=1098/2000
# Processing m=19, s=15, iteration=1760/2000
# Processing m=19, s=16, iteration=1340/2000
# Processing m=19, s=18, iteration=939/2000
# Processing m=19, s=19, iteration=688/2000
# Processing m=19, s=15, iteration=1761/2000
# Processing m=19, s=17, iteration=1099/2000
# Processing m=19, s=18, iteration=940/2000Processing m=19, s=19, iteration=689/2000Processing m=19, s=16, iteration=1341/2000Processing m=19, s=15, iteration=1762/2000
#
#
#
# Processing m=19, s=17, iteration=1100/2000
# Processing m=19, s=18, iteration=941/2000
# Processing m=19, s=19, iteration=690/2000
# Processing m=19, s=15, iteration=1763/2000
# Processing m=19, s=16, iteration=1342/2000
# Processing m=19, s=18, iteration=942/2000Processing m=19, s=19, iteration=691/2000
#
# Processing m=19, s=15, iteration=1764/2000Processing m=19, s=17, iteration=1101/2000Processing m=19, s=16, iteration=1343/2000
#
# Processing m=19, s=18, iteration=943/2000
# Processing m=19, s=15, iteration=1765/2000
#
# Processing m=19, s=19, iteration=692/2000
# Processing m=19, s=16, iteration=1344/2000
# Processing m=19, s=17, iteration=1102/2000Processing m=19, s=19, iteration=693/2000
# Processing m=19, s=15, iteration=1766/2000
# Processing m=19, s=18, iteration=944/2000
#
# Processing m=19, s=17, iteration=1103/2000Processing m=19, s=16, iteration=1345/2000
# Processing m=19, s=18, iteration=945/2000
# Processing m=19, s=15, iteration=1767/2000Processing m=19, s=19, iteration=694/2000
#
#
# Processing m=19, s=16, iteration=1346/2000
# Processing m=19, s=19, iteration=695/2000Processing m=19, s=17, iteration=1104/2000
# Processing m=19, s=18, iteration=946/2000
#
# Processing m=19, s=16, iteration=1347/2000Processing m=19, s=15, iteration=1768/2000
#
# Processing m=19, s=19, iteration=696/2000Processing m=19, s=17, iteration=1105/2000
#
# Processing m=19, s=16, iteration=1348/2000Processing m=19, s=18, iteration=947/2000
# Processing m=19, s=15, iteration=1769/2000
#
# Processing m=19, s=18, iteration=948/2000Processing m=19, s=19, iteration=697/2000
# Processing m=19, s=15, iteration=1770/2000
#
# Processing m=19, s=17, iteration=1106/2000
# Processing m=19, s=16, iteration=1349/2000
# Processing m=19, s=19, iteration=698/2000
# Processing m=19, s=18, iteration=949/2000
# Processing m=19, s=15, iteration=1771/2000
# Processing m=19, s=16, iteration=1350/2000
# Processing m=19, s=17, iteration=1107/2000
# Processing m=19, s=18, iteration=950/2000
# Processing m=19, s=15, iteration=1772/2000
# Processing m=19, s=19, iteration=699/2000
# Processing m=19, s=16, iteration=1351/2000
# Processing m=19, s=17, iteration=1108/2000
# Processing m=19, s=15, iteration=1773/2000
# Processing m=19, s=18, iteration=951/2000
# Processing m=19, s=19, iteration=700/2000
# Processing m=19, s=17, iteration=1109/2000
# Processing m=19, s=16, iteration=1352/2000
# Processing m=19, s=15, iteration=1774/2000
# Processing m=19, s=17, iteration=1110/2000
# Processing m=19, s=19, iteration=701/2000
# Processing m=19, s=16, iteration=1353/2000Processing m=19, s=18, iteration=952/2000
# Processing m=19, s=19, iteration=702/2000
# Processing m=19, s=15, iteration=1775/2000
# Processing m=19, s=17, iteration=1111/2000
#
# Processing m=19, s=16, iteration=1354/2000Processing m=19, s=18, iteration=953/2000
#
# Processing m=19, s=15, iteration=1776/2000Processing m=19, s=19, iteration=703/2000
# Processing m=19, s=17, iteration=1112/2000
#
# Processing m=19, s=16, iteration=1355/2000
# Processing m=19, s=18, iteration=954/2000
# Processing m=19, s=17, iteration=1113/2000Processing m=19, s=15, iteration=1777/2000
# Processing m=19, s=16, iteration=1356/2000
#
# Processing m=19, s=18, iteration=955/2000
# Processing m=19, s=19, iteration=704/2000
# Processing m=19, s=17, iteration=1114/2000
# Processing m=19, s=15, iteration=1778/2000
# Processing m=19, s=16, iteration=1357/2000
# Processing m=19, s=18, iteration=956/2000
# Processing m=19, s=15, iteration=1779/2000
# Processing m=19, s=19, iteration=705/2000
# Processing m=19, s=17, iteration=1115/2000
# Processing m=19, s=16, iteration=1358/2000
# Processing m=19, s=18, iteration=957/2000
# Processing m=19, s=19, iteration=706/2000
# Processing m=19, s=15, iteration=1780/2000
# Processing m=19, s=17, iteration=1116/2000
# Processing m=19, s=18, iteration=958/2000
# Processing m=19, s=16, iteration=1359/2000
# Processing m=19, s=19, iteration=707/2000
# Processing m=19, s=17, iteration=1117/2000
# Processing m=19, s=15, iteration=1781/2000
# Processing m=19, s=16, iteration=1360/2000Processing m=19, s=18, iteration=959/2000Processing m=19, s=19, iteration=708/2000
#
# Processing m=19, s=17, iteration=1118/2000
# Processing m=19, s=15, iteration=1782/2000
#
# Processing m=19, s=16, iteration=1361/2000
# Processing m=19, s=17, iteration=1119/2000
# Processing m=19, s=18, iteration=960/2000
# Processing m=19, s=16, iteration=1362/2000Processing m=19, s=17, iteration=1120/2000
# Processing m=19, s=19, iteration=709/2000
#
# Processing m=19, s=15, iteration=1783/2000
# Processing m=19, s=18, iteration=961/2000
# Processing m=19, s=17, iteration=1121/2000
# Processing m=19, s=15, iteration=1784/2000
# Processing m=19, s=16, iteration=1363/2000
# Processing m=19, s=17, iteration=1122/2000
# Processing m=19, s=19, iteration=710/2000
# Processing m=19, s=18, iteration=962/2000
# Processing m=19, s=15, iteration=1785/2000
# Processing m=19, s=16, iteration=1364/2000
# Processing m=19, s=19, iteration=711/2000
# Processing m=19, s=17, iteration=1123/2000
# Processing m=19, s=18, iteration=963/2000
# Processing m=19, s=16, iteration=1365/2000
# Processing m=19, s=15, iteration=1786/2000
# Processing m=19, s=17, iteration=1124/2000
# Processing m=19, s=19, iteration=712/2000
# Processing m=19, s=16, iteration=1366/2000
# Processing m=19, s=18, iteration=964/2000
# Processing m=19, s=15, iteration=1787/2000
# Processing m=19, s=19, iteration=713/2000
# Processing m=19, s=16, iteration=1367/2000
# Processing m=19, s=17, iteration=1125/2000
# Processing m=19, s=15, iteration=1788/2000
# Processing m=19, s=19, iteration=714/2000
# Processing m=19, s=18, iteration=965/2000
# Processing m=19, s=16, iteration=1368/2000
# Processing m=19, s=18, iteration=966/2000
# Processing m=19, s=17, iteration=1126/2000
# Processing m=19, s=19, iteration=715/2000
# Processing m=19, s=15, iteration=1789/2000
# Processing m=19, s=18, iteration=967/2000
# Processing m=19, s=16, iteration=1369/2000
# Processing m=19, s=15, iteration=1790/2000
# Processing m=19, s=19, iteration=716/2000
# Processing m=19, s=17, iteration=1127/2000
# Processing m=19, s=18, iteration=968/2000
# Processing m=19, s=16, iteration=1370/2000
# Processing m=19, s=17, iteration=1128/2000
# Processing m=19, s=15, iteration=1791/2000
# Processing m=19, s=19, iteration=717/2000
# Processing m=19, s=18, iteration=969/2000
# Processing m=19, s=17, iteration=1129/2000
# Processing m=19, s=16, iteration=1371/2000
# Processing m=19, s=15, iteration=1792/2000
# Processing m=19, s=19, iteration=718/2000
# Processing m=19, s=16, iteration=1372/2000
# Processing m=19, s=18, iteration=970/2000
# Processing m=19, s=15, iteration=1793/2000
# Processing m=19, s=17, iteration=1130/2000
# Processing m=19, s=16, iteration=1373/2000
# Processing m=19, s=15, iteration=1794/2000
# Processing m=19, s=19, iteration=719/2000Processing m=19, s=17, iteration=1131/2000Processing m=19, s=18, iteration=971/2000
# Processing m=19, s=16, iteration=1374/2000
#
#
# Processing m=19, s=15, iteration=1795/2000
# Processing m=19, s=19, iteration=720/2000Processing m=19, s=17, iteration=1132/2000
# Processing m=19, s=15, iteration=1796/2000
# Processing m=19, s=16, iteration=1375/2000
# Processing m=19, s=18, iteration=972/2000
#
# Processing m=19, s=18, iteration=973/2000
# Processing m=19, s=19, iteration=721/2000
# Processing m=19, s=16, iteration=1376/2000
# Processing m=19, s=17, iteration=1133/2000
# Processing m=19, s=15, iteration=1797/2000
# Processing m=19, s=19, iteration=722/2000Processing m=19, s=18, iteration=974/2000
#
# Processing m=19, s=15, iteration=1798/2000
# Processing m=19, s=17, iteration=1134/2000
# Processing m=19, s=16, iteration=1377/2000
# Processing m=19, s=18, iteration=975/2000
# Processing m=19, s=19, iteration=723/2000
# Processing m=19, s=17, iteration=1135/2000
# Processing m=19, s=15, iteration=1799/2000
# Processing m=19, s=16, iteration=1378/2000
# Processing m=19, s=19, iteration=724/2000Processing m=19, s=16, iteration=1379/2000Processing m=19, s=18, iteration=976/2000
#
#
# Processing m=19, s=17, iteration=1136/2000Processing m=19, s=15, iteration=1800/2000
#
# Processing m=19, s=18, iteration=977/2000Processing m=19, s=19, iteration=725/2000
#
# Processing m=19, s=16, iteration=1380/2000Processing m=19, s=15, iteration=1801/2000
#
# Processing m=19, s=17, iteration=1137/2000
# Processing m=19, s=18, iteration=978/2000Processing m=19, s=15, iteration=1802/2000Processing m=19, s=19, iteration=726/2000
#
# Processing m=19, s=16, iteration=1381/2000
# Processing m=19, s=17, iteration=1138/2000
#
# Processing m=19, s=19, iteration=727/2000
# Processing m=19, s=18, iteration=979/2000
# Processing m=19, s=16, iteration=1382/2000
# Processing m=19, s=15, iteration=1803/2000
# Processing m=19, s=18, iteration=980/2000Processing m=19, s=17, iteration=1139/2000
# Processing m=19, s=19, iteration=728/2000
#
# Processing m=19, s=17, iteration=1140/2000Processing m=19, s=15, iteration=1804/2000
#
# Processing m=19, s=16, iteration=1383/2000
# Processing m=19, s=18, iteration=981/2000
# Processing m=19, s=19, iteration=729/2000
# Processing m=19, s=15, iteration=1805/2000
# Processing m=19, s=16, iteration=1384/2000
# Processing m=19, s=17, iteration=1141/2000
# Processing m=19, s=18, iteration=982/2000
# Processing m=19, s=19, iteration=730/2000
# Processing m=19, s=15, iteration=1806/2000
# Processing m=19, s=16, iteration=1385/2000
# Processing m=19, s=17, iteration=1142/2000
# Processing m=19, s=19, iteration=731/2000
# Processing m=19, s=18, iteration=983/2000
# Processing m=19, s=15, iteration=1807/2000
# Processing m=19, s=17, iteration=1143/2000
# Processing m=19, s=16, iteration=1386/2000
# Processing m=19, s=19, iteration=732/2000
# Processing m=19, s=18, iteration=984/2000
# Processing m=19, s=16, iteration=1387/2000Processing m=19, s=15, iteration=1808/2000
# Processing m=19, s=17, iteration=1144/2000
# Processing m=19, s=18, iteration=985/2000
# Processing m=19, s=19, iteration=733/2000
#
# Processing m=19, s=17, iteration=1145/2000Processing m=19, s=15, iteration=1809/2000
# Processing m=19, s=16, iteration=1388/2000
# Processing m=19, s=18, iteration=986/2000
#
# Processing m=19, s=15, iteration=1810/2000Processing m=19, s=19, iteration=734/2000
# Processing m=19, s=17, iteration=1146/2000
# Processing m=19, s=16, iteration=1389/2000
#
# Processing m=19, s=19, iteration=735/2000
# Processing m=19, s=18, iteration=987/2000
# Processing m=19, s=17, iteration=1147/2000Processing m=19, s=19, iteration=736/2000
# Processing m=19, s=16, iteration=1390/2000Processing m=19, s=18, iteration=988/2000
#
#
# Processing m=19, s=17, iteration=1148/2000
# Processing m=19, s=18, iteration=989/2000
# Processing m=19, s=15, iteration=1811/2000
# Processing m=19, s=16, iteration=1391/2000
# Processing m=19, s=19, iteration=737/2000
# Processing m=19, s=17, iteration=1149/2000
# Processing m=19, s=18, iteration=990/2000
# Processing m=19, s=15, iteration=1812/2000
# Processing m=19, s=18, iteration=991/2000Processing m=19, s=16, iteration=1392/2000
#
# Processing m=19, s=17, iteration=1150/2000
# Processing m=19, s=15, iteration=1813/2000
# Processing m=19, s=18, iteration=992/2000
# Processing m=19, s=19, iteration=738/2000
# Processing m=19, s=17, iteration=1151/2000Processing m=19, s=16, iteration=1393/2000Processing m=19, s=15, iteration=1814/2000
#
#
# Processing m=19, s=18, iteration=993/2000
# Processing m=19, s=19, iteration=739/2000
# Processing m=19, s=16, iteration=1394/2000Processing m=19, s=17, iteration=1152/2000
#
# Processing m=19, s=15, iteration=1815/2000
# Processing m=19, s=19, iteration=740/2000
# Processing m=19, s=18, iteration=994/2000Processing m=19, s=17, iteration=1153/2000
# Processing m=19, s=16, iteration=1395/2000Processing m=19, s=15, iteration=1816/2000
#
#
# Processing m=19, s=19, iteration=741/2000
# Processing m=19, s=18, iteration=995/2000
# Processing m=19, s=15, iteration=1817/2000
# Processing m=19, s=16, iteration=1396/2000
# Processing m=19, s=17, iteration=1154/2000
# Processing m=19, s=18, iteration=996/2000
# Processing m=19, s=19, iteration=742/2000
# Processing m=19, s=16, iteration=1397/2000
# Processing m=19, s=15, iteration=1818/2000Processing m=19, s=19, iteration=743/2000
#
# Processing m=19, s=16, iteration=1398/2000Processing m=19, s=17, iteration=1155/2000
#
# Processing m=19, s=15, iteration=1819/2000
# Processing m=19, s=19, iteration=744/2000
# Processing m=19, s=18, iteration=997/2000
# Processing m=19, s=16, iteration=1399/2000
# Processing m=19, s=17, iteration=1156/2000
# Processing m=19, s=19, iteration=745/2000
# Processing m=19, s=18, iteration=998/2000
# Processing m=19, s=15, iteration=1820/2000
# Processing m=19, s=16, iteration=1400/2000
# Processing m=19, s=17, iteration=1157/2000
# Processing m=19, s=19, iteration=746/2000
# Processing m=19, s=15, iteration=1821/2000
# Processing m=19, s=16, iteration=1401/2000Processing m=19, s=17, iteration=1158/2000
# Processing m=19, s=18, iteration=999/2000
#
# Processing m=19, s=15, iteration=1822/2000Processing m=19, s=18, iteration=1000/2000
#
# ...
#
# Processing m=19, s=18, iteration=1943/2000Processing m=19, s=19, iteration=1687/2000
#
# Processing m=19, s=19, iteration=1688/2000
# Processing m=19, s=18, iteration=1944/2000
# Processing m=19, s=19, iteration=1689/2000
# Processing m=19, s=18, iteration=1945/2000
# Processing m=19, s=19, iteration=1690/2000Processing m=19, s=18, iteration=1946/2000
#
# Processing m=19, s=19, iteration=1691/2000
# Processing m=19, s=18, iteration=1947/2000Processing m=19, s=19, iteration=1692/2000
#
# Processing m=19, s=19, iteration=1693/2000Processing m=19, s=18, iteration=1948/2000
#
# Processing m=19, s=19, iteration=1694/2000Processing m=19, s=18, iteration=1949/2000
#
# Processing m=19, s=19, iteration=1695/2000Processing m=19, s=18, iteration=1950/2000
#
# Processing m=19, s=18, iteration=1951/2000Processing m=19, s=19, iteration=1696/2000
#
# Processing m=19, s=18, iteration=1952/2000
# Processing m=19, s=19, iteration=1697/2000
# Processing m=19, s=18, iteration=1953/2000
# Processing m=19, s=19, iteration=1698/2000
# Processing m=19, s=18, iteration=1954/2000Processing m=19, s=19, iteration=1699/2000
#
# Processing m=19, s=18, iteration=1955/2000
# Processing m=19, s=19, iteration=1700/2000
# Processing m=19, s=18, iteration=1956/2000
# Processing m=19, s=19, iteration=1701/2000
# Processing m=19, s=18, iteration=1957/2000
# Processing m=19, s=19, iteration=1702/2000
# Processing m=19, s=18, iteration=1958/2000Processing m=19, s=19, iteration=1703/2000
#
# Processing m=19, s=18, iteration=1959/2000
# Processing m=19, s=19, iteration=1704/2000
# Processing m=19, s=18, iteration=1960/2000
# Processing m=19, s=19, iteration=1705/2000
# Processing m=19, s=18, iteration=1961/2000
# Processing m=19, s=19, iteration=1706/2000
# Processing m=19, s=19, iteration=1707/2000
# Processing m=19, s=18, iteration=1962/2000
# Processing m=19, s=19, iteration=1708/2000
# Processing m=19, s=18, iteration=1963/2000
# Processing m=19, s=19, iteration=1709/2000
# Processing m=19, s=18, iteration=1964/2000
# Processing m=19, s=19, iteration=1710/2000
# Processing m=19, s=18, iteration=1965/2000
# Processing m=19, s=19, iteration=1711/2000
# Processing m=19, s=18, iteration=1966/2000
# Processing m=19, s=19, iteration=1712/2000
# Processing m=19, s=18, iteration=1967/2000
# Processing m=19, s=19, iteration=1713/2000
# Processing m=19, s=18, iteration=1968/2000
# Processing m=19, s=19, iteration=1714/2000
# Processing m=19, s=18, iteration=1969/2000
# Processing m=19, s=18, iteration=1970/2000
# Processing m=19, s=19, iteration=1715/2000
# Processing m=19, s=18, iteration=1971/2000
# Processing m=19, s=18, iteration=1972/2000
# Processing m=19, s=19, iteration=1716/2000
# Processing m=19, s=19, iteration=1717/2000
# Processing m=19, s=18, iteration=1973/2000
# Processing m=19, s=18, iteration=1974/2000
# Processing m=19, s=19, iteration=1718/2000
# Processing m=19, s=18, iteration=1975/2000
# Processing m=19, s=19, iteration=1719/2000
# Processing m=19, s=18, iteration=1976/2000
# Processing m=19, s=18, iteration=1977/2000
# Processing m=19, s=19, iteration=1720/2000
# Processing m=19, s=18, iteration=1978/2000
# Processing m=19, s=19, iteration=1721/2000
# Processing m=19, s=19, iteration=1722/2000
# Processing m=19, s=18, iteration=1979/2000
# Processing m=19, s=19, iteration=1723/2000
# Processing m=19, s=18, iteration=1980/2000Processing m=19, s=19, iteration=1724/2000
#
# Processing m=19, s=18, iteration=1981/2000
# Processing m=19, s=19, iteration=1725/2000
# Processing m=19, s=18, iteration=1982/2000
# Processing m=19, s=19, iteration=1726/2000
# Processing m=19, s=18, iteration=1983/2000Processing m=19, s=19, iteration=1727/2000
#
# Processing m=19, s=18, iteration=1984/2000
# Processing m=19, s=19, iteration=1728/2000
# Processing m=19, s=18, iteration=1985/2000Processing m=19, s=19, iteration=1729/2000
#
# Processing m=19, s=18, iteration=1986/2000
# Processing m=19, s=19, iteration=1730/2000
# Processing m=19, s=18, iteration=1987/2000Processing m=19, s=19, iteration=1731/2000
#
# Processing m=19, s=18, iteration=1988/2000
# Processing m=19, s=19, iteration=1732/2000
# Processing m=19, s=18, iteration=1989/2000
# Processing m=19, s=19, iteration=1733/2000
# Processing m=19, s=18, iteration=1990/2000Processing m=19, s=19, iteration=1734/2000
#
# Processing m=19, s=19, iteration=1735/2000
# Processing m=19, s=19, iteration=1736/2000
# Processing m=19, s=18, iteration=1991/2000
# Processing m=19, s=18, iteration=1992/2000Processing m=19, s=19, iteration=1737/2000
#
# Processing m=19, s=18, iteration=1993/2000
# Processing m=19, s=19, iteration=1738/2000
# Processing m=19, s=18, iteration=1994/2000
# Processing m=19, s=19, iteration=1739/2000
# Processing m=19, s=18, iteration=1995/2000
# Processing m=19, s=19, iteration=1740/2000
# Processing m=19, s=18, iteration=1996/2000
# Processing m=19, s=19, iteration=1741/2000
# Processing m=19, s=18, iteration=1997/2000Processing m=19, s=19, iteration=1742/2000
#
# Processing m=19, s=18, iteration=1998/2000
# Processing m=19, s=19, iteration=1743/2000
# Processing m=19, s=18, iteration=1999/2000Processing m=19, s=19, iteration=1744/2000
#
# Processing m=19, s=18, iteration=2000/2000Processing m=19, s=19, iteration=1745/2000
#
# Processing m=19, s=19, iteration=1746/2000
# Processing m=19, s=19, iteration=1747/2000
# Processing m=19, s=19, iteration=1748/2000
# Processing m=19, s=19, iteration=1749/2000
# Processing m=19, s=19, iteration=1750/2000
# Processing m=19, s=19, iteration=1751/2000
# Processing m=19, s=19, iteration=1752/2000
# Processing m=19, s=19, iteration=1753/2000
# Processing m=19, s=19, iteration=1754/2000
# Processing m=19, s=19, iteration=1755/2000
# Processing m=19, s=19, iteration=1756/2000
# Processing m=19, s=19, iteration=1757/2000
# Processing m=19, s=19, iteration=1758/2000
# Processing m=19, s=19, iteration=1759/2000
# Processing m=19, s=19, iteration=1760/2000
# Processing m=19, s=19, iteration=1761/2000
# Processing m=19, s=19, iteration=1762/2000
# Processing m=19, s=19, iteration=1763/2000
# Processing m=19, s=19, iteration=1764/2000
# Processing m=19, s=19, iteration=1765/2000
# Processing m=19, s=19, iteration=1766/2000
# Processing m=19, s=19, iteration=1767/2000
# Processing m=19, s=19, iteration=1768/2000
# Processing m=19, s=19, iteration=1769/2000
# Processing m=19, s=19, iteration=1770/2000
# Processing m=19, s=19, iteration=1771/2000
# Processing m=19, s=19, iteration=1772/2000
# Processing m=19, s=19, iteration=1773/2000
# Processing m=19, s=19, iteration=1774/2000
# Processing m=19, s=19, iteration=1775/2000
# Processing m=19, s=19, iteration=1776/2000
# Processing m=19, s=19, iteration=1777/2000
# Processing m=19, s=19, iteration=1778/2000
# Processing m=19, s=19, iteration=1779/2000
# Processing m=19, s=19, iteration=1780/2000
# Processing m=19, s=19, iteration=1781/2000
# Processing m=19, s=19, iteration=1782/2000
# Processing m=19, s=19, iteration=1783/2000
# Processing m=19, s=19, iteration=1784/2000
# Processing m=19, s=19, iteration=1785/2000
# Processing m=19, s=19, iteration=1786/2000
# Processing m=19, s=19, iteration=1787/2000
# Processing m=19, s=19, iteration=1788/2000
# Processing m=19, s=19, iteration=1789/2000
# Processing m=19, s=19, iteration=1790/2000
# Processing m=19, s=19, iteration=1791/2000
# Processing m=19, s=19, iteration=1792/2000
# Processing m=19, s=19, iteration=1793/2000
# Processing m=19, s=19, iteration=1794/2000
# Processing m=19, s=19, iteration=1795/2000
# Processing m=19, s=19, iteration=1796/2000
# Processing m=19, s=19, iteration=1797/2000
# Processing m=19, s=19, iteration=1798/2000
# Processing m=19, s=19, iteration=1799/2000
# Processing m=19, s=19, iteration=1800/2000
# Processing m=19, s=19, iteration=1801/2000
# Processing m=19, s=19, iteration=1802/2000
# Processing m=19, s=19, iteration=1803/2000
# Processing m=19, s=19, iteration=1804/2000
# Processing m=19, s=19, iteration=1805/2000
# Processing m=19, s=19, iteration=1806/2000
# Processing m=19, s=19, iteration=1807/2000
# Processing m=19, s=19, iteration=1808/2000
# Processing m=19, s=19, iteration=1809/2000
# Processing m=19, s=19, iteration=1810/2000
# Processing m=19, s=19, iteration=1811/2000
# Processing m=19, s=19, iteration=1812/2000
# Processing m=19, s=19, iteration=1813/2000
# Processing m=19, s=19, iteration=1814/2000
# Processing m=19, s=19, iteration=1815/2000
# Processing m=19, s=19, iteration=1816/2000
# Processing m=19, s=19, iteration=1817/2000
# Processing m=19, s=19, iteration=1818/2000
# Processing m=19, s=19, iteration=1819/2000
# Processing m=19, s=19, iteration=1820/2000
# Processing m=19, s=19, iteration=1821/2000
# Processing m=19, s=19, iteration=1822/2000
# Processing m=19, s=19, iteration=1823/2000
# Processing m=19, s=19, iteration=1824/2000
# Processing m=19, s=19, iteration=1825/2000
# Processing m=19, s=19, iteration=1826/2000
# Processing m=19, s=19, iteration=1827/2000
# Processing m=19, s=19, iteration=1828/2000
# Processing m=19, s=19, iteration=1829/2000
# Processing m=19, s=19, iteration=1830/2000
# Processing m=19, s=19, iteration=1831/2000
# Processing m=19, s=19, iteration=1832/2000
# Processing m=19, s=19, iteration=1833/2000
# Processing m=19, s=19, iteration=1834/2000
# Processing m=19, s=19, iteration=1835/2000
# Processing m=19, s=19, iteration=1836/2000
# Processing m=19, s=19, iteration=1837/2000
# Processing m=19, s=19, iteration=1838/2000
# Processing m=19, s=19, iteration=1839/2000
# Processing m=19, s=19, iteration=1840/2000
# Processing m=19, s=19, iteration=1841/2000
# Processing m=19, s=19, iteration=1842/2000
# Processing m=19, s=19, iteration=1843/2000
# Processing m=19, s=19, iteration=1844/2000
# Processing m=19, s=19, iteration=1845/2000
# Processing m=19, s=19, iteration=1846/2000
# Processing m=19, s=19, iteration=1847/2000
# Processing m=19, s=19, iteration=1848/2000
# Processing m=19, s=19, iteration=1849/2000
# Processing m=19, s=19, iteration=1850/2000
# Processing m=19, s=19, iteration=1851/2000
# Processing m=19, s=19, iteration=1852/2000
# Processing m=19, s=19, iteration=1853/2000
# Processing m=19, s=19, iteration=1854/2000
# Processing m=19, s=19, iteration=1855/2000
# Processing m=19, s=19, iteration=1856/2000
# Processing m=19, s=19, iteration=1857/2000
# Processing m=19, s=19, iteration=1858/2000
# Processing m=19, s=19, iteration=1859/2000
# Processing m=19, s=19, iteration=1860/2000
# Processing m=19, s=19, iteration=1861/2000
# Processing m=19, s=19, iteration=1862/2000
# Processing m=19, s=19, iteration=1863/2000
# Processing m=19, s=19, iteration=1864/2000
# Processing m=19, s=19, iteration=1865/2000
# Processing m=19, s=19, iteration=1866/2000
# Processing m=19, s=19, iteration=1867/2000
# Processing m=19, s=19, iteration=1868/2000
# Processing m=19, s=19, iteration=1869/2000
# Processing m=19, s=19, iteration=1870/2000
# Processing m=19, s=19, iteration=1871/2000
# Processing m=19, s=19, iteration=1872/2000
# Processing m=19, s=19, iteration=1873/2000
# Processing m=19, s=19, iteration=1874/2000
# Processing m=19, s=19, iteration=1875/2000
# Processing m=19, s=19, iteration=1876/2000
# Processing m=19, s=19, iteration=1877/2000
# Processing m=19, s=19, iteration=1878/2000
# Processing m=19, s=19, iteration=1879/2000
# Processing m=19, s=19, iteration=1880/2000
# Processing m=19, s=19, iteration=1881/2000
# Processing m=19, s=19, iteration=1882/2000
# Processing m=19, s=19, iteration=1883/2000
# Processing m=19, s=19, iteration=1884/2000
# Processing m=19, s=19, iteration=1885/2000
# Processing m=19, s=19, iteration=1886/2000
# Processing m=19, s=19, iteration=1887/2000
# Processing m=19, s=19, iteration=1888/2000
# Processing m=19, s=19, iteration=1889/2000
# Processing m=19, s=19, iteration=1890/2000
# Processing m=19, s=19, iteration=1891/2000
# Processing m=19, s=19, iteration=1892/2000
# Processing m=19, s=19, iteration=1893/2000
# Processing m=19, s=19, iteration=1894/2000
# Processing m=19, s=19, iteration=1895/2000
# Processing m=19, s=19, iteration=1896/2000
# Processing m=19, s=19, iteration=1897/2000
# Processing m=19, s=19, iteration=1898/2000
# Processing m=19, s=19, iteration=1899/2000
# Processing m=19, s=19, iteration=1900/2000
# Processing m=19, s=19, iteration=1901/2000
# Processing m=19, s=19, iteration=1902/2000
# Processing m=19, s=19, iteration=1903/2000
# Processing m=19, s=19, iteration=1904/2000
# Processing m=19, s=19, iteration=1905/2000
# Processing m=19, s=19, iteration=1906/2000
# Processing m=19, s=19, iteration=1907/2000
# Processing m=19, s=19, iteration=1908/2000
# Processing m=19, s=19, iteration=1909/2000
# Processing m=19, s=19, iteration=1910/2000
# Processing m=19, s=19, iteration=1911/2000
# Processing m=19, s=19, iteration=1912/2000
# Processing m=19, s=19, iteration=1913/2000
# Processing m=19, s=19, iteration=1914/2000
# Processing m=19, s=19, iteration=1915/2000
# Processing m=19, s=19, iteration=1916/2000
# Processing m=19, s=19, iteration=1917/2000
# Processing m=19, s=19, iteration=1918/2000
# Processing m=19, s=19, iteration=1919/2000
# Processing m=19, s=19, iteration=1920/2000
# Processing m=19, s=19, iteration=1921/2000
# Processing m=19, s=19, iteration=1922/2000
# Processing m=19, s=19, iteration=1923/2000
# Processing m=19, s=19, iteration=1924/2000
# Processing m=19, s=19, iteration=1925/2000
# Processing m=19, s=19, iteration=1926/2000
# Processing m=19, s=19, iteration=1927/2000
# Processing m=19, s=19, iteration=1928/2000
# Processing m=19, s=19, iteration=1929/2000
# Processing m=19, s=19, iteration=1930/2000
# Processing m=19, s=19, iteration=1931/2000
# Processing m=19, s=19, iteration=1932/2000
# Processing m=19, s=19, iteration=1933/2000
# Processing m=19, s=19, iteration=1934/2000
# Processing m=19, s=19, iteration=1935/2000
# Processing m=19, s=19, iteration=1936/2000
# Processing m=19, s=19, iteration=1937/2000
# Processing m=19, s=19, iteration=1938/2000
# Processing m=19, s=19, iteration=1939/2000
# Processing m=19, s=19, iteration=1940/2000
# Processing m=19, s=19, iteration=1941/2000
# Processing m=19, s=19, iteration=1942/2000
# Processing m=19, s=19, iteration=1943/2000
# Processing m=19, s=19, iteration=1944/2000
# Processing m=19, s=19, iteration=1945/2000
# Processing m=19, s=19, iteration=1946/2000
# Processing m=19, s=19, iteration=1947/2000
# Processing m=19, s=19, iteration=1948/2000
# Processing m=19, s=19, iteration=1949/2000
# Processing m=19, s=19, iteration=1950/2000
# Processing m=19, s=19, iteration=1951/2000
# Processing m=19, s=19, iteration=1952/2000
# Processing m=19, s=19, iteration=1953/2000
# Processing m=19, s=19, iteration=1954/2000
# Processing m=19, s=19, iteration=1955/2000
# Processing m=19, s=19, iteration=1956/2000
# Processing m=19, s=19, iteration=1957/2000
# Processing m=19, s=19, iteration=1958/2000
# Processing m=19, s=19, iteration=1959/2000
# Processing m=19, s=19, iteration=1960/2000
# Processing m=19, s=19, iteration=1961/2000
# Processing m=19, s=19, iteration=1962/2000
# Processing m=19, s=19, iteration=1963/2000
# Processing m=19, s=19, iteration=1964/2000
# Processing m=19, s=19, iteration=1965/2000
# Processing m=19, s=19, iteration=1966/2000
# Processing m=19, s=19, iteration=1967/2000
# Processing m=19, s=19, iteration=1968/2000
# Processing m=19, s=19, iteration=1969/2000
# Processing m=19, s=19, iteration=1970/2000
# Processing m=19, s=19, iteration=1971/2000
# Processing m=19, s=19, iteration=1972/2000
# Processing m=19, s=19, iteration=1973/2000
# Processing m=19, s=19, iteration=1974/2000
# Processing m=19, s=19, iteration=1975/2000
# Processing m=19, s=19, iteration=1976/2000
# Processing m=19, s=19, iteration=1977/2000
# Processing m=19, s=19, iteration=1978/2000
# Processing m=19, s=19, iteration=1979/2000
# Processing m=19, s=19, iteration=1980/2000
# Processing m=19, s=19, iteration=1981/2000
# Processing m=19, s=19, iteration=1982/2000
# Processing m=19, s=19, iteration=1983/2000
# Processing m=19, s=19, iteration=1984/2000
# Processing m=19, s=19, iteration=1985/2000
# Processing m=19, s=19, iteration=1986/2000
# Processing m=19, s=19, iteration=1987/2000
# Processing m=19, s=19, iteration=1988/2000
# Processing m=19, s=19, iteration=1989/2000
# Processing m=19, s=19, iteration=1990/2000
# Processing m=19, s=19, iteration=1991/2000
# Processing m=19, s=19, iteration=1992/2000
# Processing m=19, s=19, iteration=1993/2000
# Processing m=19, s=19, iteration=1994/2000
# Processing m=19, s=19, iteration=1995/2000
# Processing m=19, s=19, iteration=1996/2000
# Processing m=19, s=19, iteration=1997/2000
# Processing m=19, s=19, iteration=1998/2000
# Processing m=19, s=19, iteration=1999/2000
# Processing m=19, s=19, iteration=2000/2000

# %%
Figure = plt.figure(figsize=(5, 5))
F1 = Figure.add_subplot(1, 1, 1)
ESR = F1.imshow(success_plot)
plt.colorbar(ESR, ax=F1, pad=0.2)
F1.set_xlabel("Smax")
F1.set_ylabel("M")
F1.set_title("Probability of ESR")
plt.savefig('noisy_20_ESR_small_sig.png')

Figure = plt.figure(figsize=(5, 5))
F2 = Figure.add_subplot(1, 1,1)
Error = F2.imshow(avg_error_plot)
plt.colorbar(Error, ax=F2, pad=0.2)
F2.set_xlabel("smax")
F2.set_ylabel("M")
F2.set_title("Average Error Plot")
plt.savefig('noisy_20_Err_small_sig.png')

# %%
Figure = plt.figure(figsize=(5, 5))
F1 = Figure.add_subplot(1, 1, 1)
ESR = F1.imshow(success_plot_large)
plt.colorbar(ESR, ax=F1, pad=0.2)
F1.set_xlabel("Smax")
F1.set_ylabel("M")
F1.set_title("Probability of ESR")
plt.savefig('noisy_20_ESR_large_sig.png')

Figure = plt.figure(figsize=(5, 5))
F2 = Figure.add_subplot(1, 1,1)
Error = F2.imshow(avg_error_plot_large)
plt.colorbar(Error, ax=F2, pad=0.2)
F2.set_xlabel("smax")
F2.set_ylabel("M")
F2.set_title("Average Error Plot")
plt.savefig('noisy_20_Err_large_sig.png')
